# %% [markdown]
# # NETFLIX FILMU ANALIZE

# %% [markdown]
# # Projekto hipotezes:
# - Ar Netflix daugiau fokusuojasi i filmu ar serialu kurima ?
# - Ar pandemijos metais (paskutiniai 2 metai) krito naujo turinio kurimas ?
# - Koks filmu ir tvshows rating yra populiariausias ?
# - Kurios salys kuria daugiausia Netflix turinio ?

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import mysql.connector 
import json

# %%
with open("credentials.json", 'r') as fr:
    credentials = json.load(fr)

mydb = mysql.connector.connect(
    host="localhost", # IP address
    port="3306",
    user= credentials["user"],
    password= credentials["pass"],
)
cursor = mydb.cursor()
cursor.execute('USE Baigiamasis_darbas')
netflix = pd.read_sql('SELECT * FROM Netflix_titles', con=mydb)
netflix
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# ...      ...      ...                    ...              ...
# 8783   s8803    Movie                 Zodiac    David Fincher
# 8784   s8804  TV Show            Zombie Dumb
# 8785   s8805    Movie             Zombieland  Ruben Fleischer
# 8786   s8806    Movie                   Zoom     Peter Hewitt
# 8787   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                        United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8783  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8784
# 8785  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8786  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8787  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8783   November 20, 2019          2007      R    158 min
# 8784        July 1, 2019          2018  TV-Y7  2 Seasons
# 8785    November 1, 2019          2009      R     88 min
# 8786    January 11, 2020          2006     PG     88 min
# 8787       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8783                     Cult Movies, Dramas, Thrillers
# 8784             Kids' TV, Korean TV Shows, TV Comedies
# 8785                            Comedies, Horror Movies
# 8786                 Children & Family Movies, Comedies
# 8787     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8783  A political cartoonist, a crime reporter and a...
# 8784  While living alone in a spooky town, a young g...
# 8785  Looking to survive in a world taken over by zo...
# 8786  Dragged from civilian life, a former superhero...
# 8787  A scrappy but poor boy worms his way into a ty...
#
# [8788 rows x 12 columns]

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8788 entries, 0 to 8787
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8788 non-null   object
#  1   type          8788 non-null   object
#  2   title         8788 non-null   object
#  3   director      8788 non-null   object
#  4   cast          8788 non-null   object
#  5   country       8788 non-null   object
#  6   date_added    8788 non-null   object
#  7   release_year  8788 non-null   int64
#  8   rating        8788 non-null   object
#  9   duration      8788 non-null   object
#  10  listed_in     8788 non-null   object
#  11  description   8788 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 824.0+ KB

# %%
#Daugiau sukurta movies
netflix['type'].value_counts()
# Out:
# Movie      6115
# TV Show    2673
# Name: type, dtype: int64

# %%
#Apskaiciuojame procentines vertes Tv Shows ir Movies 
netflix['type'].value_counts(normalize=True) * 100
# Out:
# Movie      69.583523
# TV Show    30.416477
# Name: type, dtype: float64

# %%
# Parodome procentines vertes diagramoje (gautas procentines reiksmes suapvalinau)
labels = 'Tv show', 'Movie'
sizes = [30, 70]
explode = (0, 0.1) 
colors = ( "red","white") 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, colors = colors, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  
ax1.legend(
          title="List",
          loc="center left",
          bbox_to_anchor=(1, 0, 0, 1))
plt.tight_layout()
plt.show()

# %%
netflixmovie = netflix[netflix['type'] == 'Movie']
netflixmovie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8782   s8802  Movie                           Zinzana
# 8783   s8803  Movie                            Zodiac
# 8785   s8805  Movie                        Zombieland
# 8786   s8806  Movie                              Zoom
# 8787   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8782                Majid Al Ansari
# 8783                  David Fincher
# 8785                Ruben Fleischer
# 8786                   Peter Hewitt
# 8787                    Mozez Singh
#
#                                                    cast  \
# 0
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8782  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8783  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8785  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8786  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8787  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 6                                                        September 24, 2021
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                         United States  September 24, 2021
# 12                              Germany, Czech Republic  September 23, 2021
# ...                                                 ...                 ...
# 8782                       United Arab Emirates, Jordan       March 9, 2016
# 8783                                      United States   November 20, 2019
# 8785                                      United States    November 1, 2019
# 8786                                      United States    January 11, 2020
# 8787                                              India       March 2, 2019
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8782          2015  TV-MA   96 min
# 8783          2007      R  158 min
# 8785          2009      R   88 min
# 8786          2006     PG   88 min
# 8787          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8782           Dramas, International Movies, Thrillers
# 8783                    Cult Movies, Dramas, Thrillers
# 8785                           Comedies, Horror Movies
# 8786                Children & Family Movies, Comedies
# 8787    Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 6     Equestria's divided. But a bright-eyed hero be...
# 7     On a photo shoot in Ghana, an American model s...
# 9     A woman adjusting to life after a loss contend...
# 12    After most of her family is murdered in a terr...
# ...                                                 ...
# 8782  Recovering alcoholic Talal wakes up inside a s...
# 8783  A political cartoonist, a crime reporter and a...
# 8785  Looking to survive in a world taken over by zo...
# 8786  Dragged from civilian life, a former superhero...
# 8787  A scrappy but poor boy worms his way into a ty...
#
# [6115 rows x 12 columns]

# %%
netflixtvshow = netflix[netflix['type'] == 'TV Show']
netflixtvshow
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8776   s8796  TV Show        Yu-Gi-Oh! Arc-V
# 8777   s8797  TV Show             Yunus Emre
# 8778   s8798  TV Show              Zak Storm
# 8781   s8801  TV Show     Zindagi Gulzar Hai
# 8784   s8804  TV Show            Zombie Dumb
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8776  Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# 8777  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# 8778  Michael Johnston, Jessica Gee-George, Christin...
# 8781  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8784
#
#                                             country          date_added  \
# 1                                      South Africa  September 24, 2021
# 2                                                    September 24, 2021
# 3                                                    September 24, 2021
# 4                                             India  September 24, 2021
# 5                                                    September 24, 2021
# ...                                             ...                 ...
# 8776                                  Japan, Canada         May 1, 2018
# 8777                                         Turkey    January 17, 2017
# 8778  United States, France, South Korea, Indonesia  September 13, 2018
# 8781                                       Pakistan   December 15, 2016
# 8784                                                       July 1, 2019
#
#       release_year rating   duration  \
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# 5             2021  TV-MA   1 Season
# ...            ...    ...        ...
# 8776          2015  TV-Y7  2 Seasons
# 8777          2016  TV-PG  2 Seasons
# 8778          2016  TV-Y7  3 Seasons
# 8781          2012  TV-PG   1 Season
# 8784          2018  TV-Y7  2 Seasons
#
#                                               listed_in  \
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 8776                             Anime Series, Kids' TV
# 8777                  International TV Shows, TV Dramas
# 8778                                           Kids' TV
# 8781  International TV Shows, Romantic TV Shows, TV ...
# 8784             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# 5     The arrival of a charismatic young priest brin...
# ...                                                 ...
# 8776  Now that he's discovered the Pendulum Summonin...
# 8777  During the Mongol invasions, Yunus Emre leaves...
# 8778  Teen surfer Zak Storm is mysteriously transpor...
# 8781  Strong-willed, middle-class Kashaf and carefre...
# 8784  While living alone in a spooky town, a young g...
#
# [2673 rows x 12 columns]

# %%
years = netflix['release_year'].value_counts()
years
# Out:
# 2018    1145
# 2017    1030
# 2019    1026
# 2020     952
# 2016     901
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
netflix['release_year'].head(2)
# Out:
# 0    2020
# 1    2021
# Name: release_year, dtype: int64

# %%
#yearspandemic = [2021, 20]
#sns.countplot(x='type', data=netflix)
plt.figure(figsize=(12,5)) 
sns.lineplot(x='release_year',y='type',data=netflix,color="r")
plt.show()

# %%
plt.figure(figsize=(12,10))
ax = sns.countplot(x="rating", data=netflix, palette="Set2", order=netflix['rating'].value_counts().index[0:15])
